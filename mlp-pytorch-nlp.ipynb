# %% [markdown]
# <a href="https://www.kaggle.com/code/evelynartoria/mlp-pytorch-nlp?scriptVersionId=187285587" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/us-baby-names/StateNames.csv
# /kaggle/input/us-baby-names/NationalReadMe.pdf
# /kaggle/input/us-baby-names/hashes.txt
# /kaggle/input/us-baby-names/NationalNames.csv
# /kaggle/input/us-baby-names/StateReadMe.pdf
# /kaggle/input/us-baby-names/database.sqlite

# %% [markdown]
# # Introduction
# - This is a notebook presesnting how to build a MLP (Multilayer perceptron) for character level machine learning model
# - this notebook follows the Building makemore Part 2: MLP by Andrej Karpathy (https://www.youtube.com/watch?v=TCH_1BHY58I&list=PLAqhIrjkxbuWI23v9cThsA9GvCAUhRvKZ&index=4)

# %% [markdown]
# # Import needed libraries

# %%
from tqdm import tqdm
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import TensorDataset, DataLoader, random_split

# %% [markdown]
# # Device agnostic code

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_default_device(device)
generator = torch.Generator(device=device)
print(f"default devcie set to {device}")
# Out:
# default devcie set to cpu

# %% [markdown]
# # Read the names csv file

# %%
names_csv = pd.read_csv("/kaggle/input/us-baby-names/NationalNames.csv")
names_csv
# Out:
#               Id       Name  Year Gender  Count
# 0              1       Mary  1880      F   7065
# 1              2       Anna  1880      F   2604
# 2              3       Emma  1880      F   2003
# 3              4  Elizabeth  1880      F   1939
# 4              5     Minnie  1880      F   1746
# ...          ...        ...   ...    ...    ...
# 1825428  1825429     Zykeem  2014      M      5
# 1825429  1825430     Zymeer  2014      M      5
# 1825430  1825431    Zymiere  2014      M      5
# 1825431  1825432      Zyran  2014      M      5
# 1825432  1825433      Zyrin  2014      M      5
#
# [1825433 rows x 5 columns]

# %% [markdown]
# # Prepare the data

# %%
names = names_csv["Name"].values
vocab = set("".join(names))
print(vocab)
# Out:
# {'M', 'T', 'i', 'z', 'B', 'u', 'N', 'b', 'R', 'K', 'a', 'U', 'c', 'Y', 'V', 'x', 'm', 'v', 'W', 'o', 'G', 'l', 'e', 'f', 'F', 'A', 'p', 'E', 'I', 'C', 'L', 'n', 'k', 'h', 'w', 'X', 'Z', 'd', 'q', 'D', 'j', 's', 'r', 'g', 'O', 'H', 'J', 'P', 'Q', 'S', 'y', 't'}

# %%
# string to id
stoi = {c:v+1 for v, c in enumerate(vocab)}
stoi["."] = 0

# id to string
itos = {v:c for c, v in stoi.items()}

print(stoi["g"])
print(itos[21])

vocab_size = len(stoi)
print(f"vocab size --> {vocab_size}")
# Out:
# 44
# G
# vocab size --> 53

# %%
def make_dataset(context_size, names, log: bool):

    inputs = []
    labels = []

    for name in names[:1000000]:
        chs = name + "."
        context = ["."] * context_size

        for ch in chs:
            idx = stoi[ch]
            inputs.append([stoi[ch_context] for ch_context in context])
            labels.append(idx)
            
            if log:
                print(f"for context {context}, expect --> {itos[idx]}")
            
            context = context[1:] + list(ch)
    
    if log:
        print(inputs)
    
    inputs = torch.tensor(inputs)
    labels = torch.tensor(labels)
    dataset = TensorDataset(inputs, labels)
    
    if log:
        print(inputs.shape)
        print(labels.shape)
    return dataset

# %%
context_size = 4
names_dataset = make_dataset(context_size=context_size, names=names, log=False)

# %%
train_split = int(len(names_dataset) * 0.8)
test_split = int(len(names_dataset) - train_split)
train_dataset, test_dataset = random_split(dataset=names_dataset, lengths=[train_split, test_split])

# %%
batch_size = 64
train_dataloader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, generator=generator)
test_dataloader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=True, generator=generator)

# %% [markdown]
# # Sample from the dataloader

# %%
batch_sample_inputs, batch_sample_labels = next(iter(test_dataloader))
print(batch_sample_inputs.shape, batch_sample_labels.shape)
# Out:
# torch.Size([64, 4]) torch.Size([64])

# %% [markdown]
# # Model

# %%
# n_embd is the number of values used to represent each token
n_embd = 5
lookup_table = torch.randn(size=(vocab_size, n_embd))
print(lookup_table)
# Out:
# tensor([[ 7.6655e-01,  1.8211e-01, -1.5845e+00, -1.4882e-01,  3.3624e-01],
#         [ 2.8833e-01, -1.9351e-01,  2.9328e-01,  3.3140e-01, -1.8512e-01],
#         [ 1.0245e+00,  7.8906e-01,  1.9254e-01,  2.2420e-02, -1.2740e+00],
#         [-6.5269e-01, -8.8686e-02,  8.0516e-02, -5.9009e-01,  2.1242e+00],
#         [ 1.8560e+00, -5.0954e-01, -3.8792e-01,  1.6668e+00,  5.0784e-01],
#         [ 7.7819e-01, -3.2264e-01, -1.2609e+00,  9.9239e-01,  4.5334e-01],
#         [ 6.5151e-01,  2.5334e-01,  2.2904e-01, -5.2549e-01,  6.6740e-02],
#         [-3.0718e-01, -7.0428e-01,  8.1581e-02, -2.4455e-01, -5.6492e-01],
#         [-6.3053e-01,  1.9804e+00,  2.9209e-01,  1.1195e+00, -7.8012e-01],
#         [ 9.6694e-01,  1.2035e+00, -9.2423e-01,  1.1622e+00,  1.1018e+00],
#         [ 7.3404e-01, -1.7948e+00, -1.6293e+00, -5.4670e-01, -3.2266e-01],
#         [ 1.1690e+00,  1.8100e-01,  6.1795e-01,  1.0565e+00,  1.6915e-01],
#         [ 2.6565e-01, -5.3859e-01,  6.3124e-01, -2.2384e-01,  8.2131e-01],
#         [ 1.4778e+00,  2.3383e-01,  1.3707e+00,  9.1805e-01, -4.5764e-01],
#         [ 9.1624e-02, -9.2548e-01, -7.0230e-01,  9.2518e-01, -6.1766e-02],
#         [ 1.3359e-01, -1.0272e+00,  1.0315e+00, -9.4795e-01,  2.4367e-01],
#         [ 2.6476e-01,  2.1633e+00, -2.0671e-02, -1.3341e+00, -1.5141e+00],
#         [ 4.7933e-01, -1.9032e+00, -1.5627e+00,  5.6622e-01,  6.0490e-01],
#         [ 2.0198e+00, -9.1449e-01,  6.4224e-01, -2.6970e-02,  7.4084e-01],
#         [ 8.0680e-01,  1.2381e+00, -7.4156e-01, -3.1838e-01, -1.8224e-01],
#         [ 4.8508e-01, -6.3427e-03,  9.8792e-01,  1.1444e+00,  9.2835e-01],
#         [ 1.0610e+00,  1.5498e+00, -1.9360e-01,  1.5160e+00, -4.9398e-01],
#         [ 1.6243e-01,  8.5726e-01, -8.6757e-01,  8.4985e-01, -8.3406e-01],
#         [ 1.4064e+00,  6.7664e-01,  3.5196e-01, -7.1635e-01, -3.0754e-02],
#         [ 1.2867e+00,  1.0969e+00,  2.6888e+00, -1.2912e+00,  1.0424e+00],
#         [-1.0926e-01,  1.0183e+00,  8.5455e-01,  4.2661e-01, -2.6229e-01],
#         [ 5.3902e-01,  7.8270e-01,  1.8141e+00,  8.5920e-01, -5.7852e-01],
#         [-1.7907e+00,  6.0261e-01, -1.4559e+00, -9.8128e-01, -1.3618e+00],
#         [-8.2682e-01, -6.9403e-01, -1.1291e+00,  1.3420e+00,  1.1599e+00],
#         [ 3.6807e-01,  1.0544e+00, -6.2243e-01, -1.6085e+00,  1.0523e+00],
#         [ 2.5455e-01, -1.5567e+00,  5.5992e-02,  1.0560e+00,  6.3075e-01],
#         [-1.1578e+00,  6.5680e-02,  2.0796e+00, -4.9678e-01,  2.2864e-02],
#         [-2.9878e-01, -1.0289e+00, -1.5236e-01, -2.0522e+00,  5.5572e-01],
#         [-1.1686e+00, -8.6517e-02, -4.6183e-01, -3.9604e-01,  2.4075e+00],
#         [-2.5144e+00, -1.7160e-01, -1.1705e+00, -1.1612e+00, -4.6981e-01],
#         [-1.0434e-01, -9.5071e-01,  1.6486e+00,  1.9048e+00,  9.5319e-01],
#         [-7.2171e-02,  7.3502e-01,  2.3002e-01,  6.9394e-01, -6.0352e-01],
#         [ 5.0167e-01, -2.3832e-01,  1.7259e-01,  3.5227e-01, -1.5016e-01],
#         [ 5.8180e-01,  9.6529e-01,  6.3601e-01,  1.7153e+00, -6.6933e-03],
#         [-4.6933e-01,  3.9820e-01,  3.2800e-01,  6.9113e-01, -7.5511e-01],
#         [-4.2688e-01, -9.3599e-01, -3.5184e-01,  7.6902e-01,  1.1713e+00],
#         [ 2.4207e-01,  9.0406e-01,  2.6280e-01, -1.0399e-02, -4.9478e-01],
#         [-6.6111e-01, -1.3250e+00, -2.2460e-02,  1.5344e+00,  8.9059e-01],
#         [-1.1932e+00,  1.7947e+00, -3.6055e-01,  3.0004e-02, -2.9759e-01],
#         [-1.4859e+00, -1.0026e+00, -4.5463e-01,  1.9464e+00, -1.7564e+00],
#         [-2.0974e-03,  1.9080e+00,  1.7460e-01, -2.6677e+00, -5.1827e-01],
#         [-1.3118e-01,  5.2425e-01,  1.0849e-01, -1.1785e-01,  8.2235e-02],
#         [-2.7097e+00, -7.7804e-01, -1.0382e-01, -4.4605e-01,  7.6871e-01],
#         [-2.6285e-01, -3.7431e-01,  2.0692e-01,  1.6524e-01, -7.3898e-01],
#         [-7.7028e-01,  8.3504e-01, -5.1634e-01, -1.1414e+00, -2.0836e+00],
#         [-1.3209e+00,  9.9370e-01,  7.9936e-01, -2.3465e-01,  1.5263e+00],
#         [-1.6595e+00,  4.4045e-01, -8.4593e-01,  1.9931e-01,  4.5589e-01],
#         [-1.2861e+00, -5.3557e-01, -8.7853e-01, -1.8289e-01,  3.6884e-01]])

# %%
random_char_idx = torch.randint(0, vocab_size, (1,)).item()
random_char = itos[random_char_idx]
print(random_char)
print(lookup_table[random_char_idx]) # the random char is going to get n_embd values related to itself
# Out:
# M
# tensor([ 0.2883, -0.1935,  0.2933,  0.3314, -0.1851])

# %%
random_char_idx_tensor = torch.randint(0, vocab_size, (8, 4))
stacked = torch.stack([idx for idx in random_char_idx_tensor])

for stack in stacked:
    input_chs = ""
    for v in stack:
        input_chs += itos[v.item()]
        
    print(f"for input {input_chs} --> {stack}")

print(random_char)
print(lookup_table[stacked]) # the random char is going to get n_embd values related to itself
print(lookup_table[stacked].shape) # shape of B x T x C --> batches by inputs by channels
# Out:
# for input jCrV --> tensor([41, 30, 43, 15])
# for input cUA. --> tensor([13, 12, 26,  0])
# for input LBnI --> tensor([31,  5, 32, 29])
# for input cYgi --> tensor([13, 14, 44,  3])
# for input yPyI --> tensor([51, 48, 51, 29])
# for input aJbf --> tensor([11, 47,  8, 24])
# for input PZMl --> tensor([48, 37,  1, 22])
# for input DiEa --> tensor([40,  3, 28, 11])
# M
# tensor([[[ 0.2421,  0.9041,  0.2628, -0.0104, -0.4948],
#          [ 0.2546, -1.5567,  0.0560,  1.0560,  0.6307],
#          [-1.1932,  1.7947, -0.3605,  0.0300, -0.2976],
#          [ 0.1336, -1.0272,  1.0315, -0.9480,  0.2437]],
#
#         [[ 1.4778,  0.2338,  1.3707,  0.9181, -0.4576],
#          [ 0.2656, -0.5386,  0.6312, -0.2238,  0.8213],
#          [ 0.5390,  0.7827,  1.8141,  0.8592, -0.5785],
#          [ 0.7665,  0.1821, -1.5845, -0.1488,  0.3362]],
#
#         [[-1.1578,  0.0657,  2.0796, -0.4968,  0.0229],
#          [ 0.7782, -0.3226, -1.2609,  0.9924,  0.4533],
#          [-0.2988, -1.0289, -0.1524, -2.0522,  0.5557],
#          [ 0.3681,  1.0544, -0.6224, -1.6085,  1.0523]],
#
#         [[ 1.4778,  0.2338,  1.3707,  0.9181, -0.4576],
#          [ 0.0916, -0.9255, -0.7023,  0.9252, -0.0618],
#          [-1.4859, -1.0026, -0.4546,  1.9464, -1.7564],
#          [-0.6527, -0.0887,  0.0805, -0.5901,  2.1242]],
#
#         [[-1.6595,  0.4405, -0.8459,  0.1993,  0.4559],
#          [-0.2629, -0.3743,  0.2069,  0.1652, -0.7390],
#          [-1.6595,  0.4405, -0.8459,  0.1993,  0.4559],
#          [ 0.3681,  1.0544, -0.6224, -1.6085,  1.0523]],
#
#         [[ 1.1690,  0.1810,  0.6179,  1.0565,  0.1691],
#          [-2.7097, -0.7780, -0.1038, -0.4461,  0.7687],
#          [-0.6305,  1.9804,  0.2921,  1.1195, -0.7801],
#          [ 1.2867,  1.0969,  2.6888, -1.2912,  1.0424]],
#
#         [[-0.2629, -0.3743,  0.2069,  0.1652, -0.7390],
#          [ 0.5017, -0.2383,  0.1726,  0.3523, -0.1502],
#          [ 0.2883, -0.1935,  0.2933,  0.3314, -0.1851],
#          [ 0.1624,  0.8573, -0.8676,  0.8498, -0.8341]],
#
#         [[-0.4269, -0.9360, -0.3518,  0.7690,  1.1713],
#          [-0.6527, -0.0887,  0.0805, -0.5901,  2.1242],
#          [-0.8268, -0.6940, -1.1291,  1.3420,  1.1599],
#          [ 1.1690,  0.1810,  0.6179,  1.0565,  0.1691]]])
# torch.Size([8, 4, 5])

# %%
# another way is to use nn.Embedding()
emb_table = nn.Embedding(num_embeddings=vocab_size, embedding_dim=n_embd)
random_char_idx_tensor = torch.randint(0, vocab_size, (8, 4), dtype=torch.long)


embedded = emb_table(random_char_idx_tensor)

print(random_char)
print(embedded.shape) # B x T x C (batches by time by channels)
# time is the number of inputs, channels is the number of values for each input
print(embedded)
# Out:
# M
# torch.Size([8, 4, 5])
# tensor([[[-1.5672, -0.4502,  0.1516, -1.2840, -0.5506],
#          [-0.3016,  0.5590,  0.7414, -0.7917,  1.1247],
#          [-0.0613, -2.0487, -1.2371, -0.8480, -0.5769],
#          [-0.2281,  0.0809, -0.7191,  0.3620,  0.5775]],
#
#         [[ 1.5874, -0.3137, -0.7653,  1.6016, -0.2799],
#          [ 0.1332,  0.2517, -0.6478,  1.4070, -0.2854],
#          [-1.0686,  0.0370,  1.1281,  0.6733,  0.0116],
#          [-0.0613, -2.0487, -1.2371, -0.8480, -0.5769]],
#
#         [[ 2.4157,  1.2876,  0.7653,  0.3756, -1.4121],
#          [-0.2281,  0.0809, -0.7191,  0.3620,  0.5775],
#          [-1.3477,  0.1816,  1.6845,  0.0211, -2.5997],
#          [-1.3470, -0.6315,  0.3968,  0.9489, -0.0694]],
#
#         [[ 0.4430, -0.6886, -0.4542, -0.8186,  0.4243],
#          [-1.1782,  0.9478, -0.5819,  1.5804, -0.7754],
#          [-0.2281,  0.0809, -0.7191,  0.3620,  0.5775],
#          [ 1.0905,  0.9305, -0.6677, -0.4777, -0.4832]],
#
#         [[-0.5870, -0.6108, -0.2293,  1.0131, -1.0357],
#          [-0.5543,  2.1708,  0.3754, -1.0827, -0.6425],
#          [ 1.0905,  0.9305, -0.6677, -0.4777, -0.4832],
#          [ 0.0341,  0.3150, -1.1143, -0.7945, -1.3806]],
#
#         [[ 1.8834, -0.0354, -1.7323, -0.0945,  2.2603],
#          [-2.1177,  0.0516, -0.5114, -0.8240,  1.0466],
#          [-0.3016,  0.5590,  0.7414, -0.7917,  1.1247],
#          [ 0.2213, -0.5983,  0.0290,  0.6495,  1.8160]],
#
#         [[ 1.0905,  0.9305, -0.6677, -0.4777, -0.4832],
#          [-0.2281,  0.0809, -0.7191,  0.3620,  0.5775],
#          [ 0.6903,  0.1706, -0.1770,  0.2348,  0.9557],
#          [ 0.8902, -0.0825,  0.7212, -0.0372, -0.4615]],
#
#         [[ 1.4717,  0.6309,  0.6714,  1.2086, -0.2923],
#          [ 1.5862,  0.1037, -1.3542, -0.7018, -0.4843],
#          [-0.5720, -0.1918,  0.3433, -0.4883,  0.0595],
#          [ 0.2816,  0.2190,  1.0088,  0.9318,  0.1815]]],
#        grad_fn=<EmbeddingBackward0>)

# %%
embedded = emb_table(random_char_idx_tensor)

# Batches, Time and Channels
B, T, C = embedded.shape
#embedded = embedded.reshape(B, T*C) # proper shape to multiply the embedded information by weights
embedded = embedded.view(B, T*C)
print(embedded.shape)
print(embedded)
# Out:
# torch.Size([8, 20])
# tensor([[-1.5672, -0.4502,  0.1516, -1.2840, -0.5506, -0.3016,  0.5590,  0.7414,
#          -0.7917,  1.1247, -0.0613, -2.0487, -1.2371, -0.8480, -0.5769, -0.2281,
#           0.0809, -0.7191,  0.3620,  0.5775],
#         [ 1.5874, -0.3137, -0.7653,  1.6016, -0.2799,  0.1332,  0.2517, -0.6478,
#           1.4070, -0.2854, -1.0686,  0.0370,  1.1281,  0.6733,  0.0116, -0.0613,
#          -2.0487, -1.2371, -0.8480, -0.5769],
#         [ 2.4157,  1.2876,  0.7653,  0.3756, -1.4121, -0.2281,  0.0809, -0.7191,
#           0.3620,  0.5775, -1.3477,  0.1816,  1.6845,  0.0211, -2.5997, -1.3470,
#          -0.6315,  0.3968,  0.9489, -0.0694],
#         [ 0.4430, -0.6886, -0.4542, -0.8186,  0.4243, -1.1782,  0.9478, -0.5819,
#           1.5804, -0.7754, -0.2281,  0.0809, -0.7191,  0.3620,  0.5775,  1.0905,
#           0.9305, -0.6677, -0.4777, -0.4832],
#         [-0.5870, -0.6108, -0.2293,  1.0131, -1.0357, -0.5543,  2.1708,  0.3754,
#          -1.0827, -0.6425,  1.0905,  0.9305, -0.6677, -0.4777, -0.4832,  0.0341,
#           0.3150, -1.1143, -0.7945, -1.3806],
#         [ 1.8834, -0.0354, -1.7323, -0.0945,  2.2603, -2.1177,  0.0516, -0.5114,
#          -0.8240,  1.0466, -0.3016,  0.5590,  0.7414, -0.7917,  1.1247,  0.2213,
#          -0.5983,  0.0290,  0.6495,  1.8160],
#         [ 1.0905,  0.9305, -0.6677, -0.4777, -0.4832, -0.2281,  0.0809, -0.7191,
#           0.3620,  0.5775,  0.6903,  0.1706, -0.1770,  0.2348,  0.9557,  0.8902,
#          -0.0825,  0.7212, -0.0372, -0.4615],
#         [ 1.4717,  0.6309,  0.6714,  1.2086, -0.2923,  1.5862,  0.1037, -1.3542,
#          -0.7018, -0.4843, -0.5720, -0.1918,  0.3433, -0.4883,  0.0595,  0.2816,
#           0.2190,  1.0088,  0.9318,  0.1815]], grad_fn=<ViewBackward0>)

# %%
hidden_units = 100
w1 = torch.randn(size=(T*C, hidden_units))
b1 = torch.randn(size=(hidden_units,))
result = torch.tanh(embedded @ w1 + b1)
print(result.shape)
# Out:
# torch.Size([8, 100])

# %%
w2 = torch.randn(size=(100, vocab_size))
b2 = torch.randn(size=(vocab_size,))
logits = result @ w2 + b2
print(logits.shape) # B by vocab_size, each batch has 1 output and there are vocab_size possible characters as an output
# Out:
# torch.Size([8, 53])

# %%
percents = torch.softmax(logits, dim=1)
preds = torch.argmax(percents, dim=1)
print(percents.shape)
print(percents[0].sum())
print(preds.shape, preds)
# Out:
# torch.Size([8, 53])
# tensor(1.0000, grad_fn=<SumBackward0>)
# torch.Size([8]) tensor([31, 29, 51, 52, 42,  3, 51, 14])

# %% [markdown]
# # Turn all this mess into a model class

# %%
# vocab_size --> number of possible characters
# n_embd --> number of values associated with each token
class MLP(nn.Module):
    def __init__(self, vocab_size, context_size, n_embd):
        super().__init__()
        
        self.emb_table = nn.Embedding(num_embeddings=vocab_size, embedding_dim=n_embd)
        self.linear1 = nn.Linear(in_features=context_size*n_embd, out_features=8*8, bias=True)
        self.linear2 = nn.Linear(in_features=8*8, out_features=8*8*8, bias=True)
        self.linear3 = nn.Linear(in_features=8*8*8, out_features=vocab_size, bias=True)
        
        self.act_fn = nn.Tanh()
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.emb_table(x)
        B, T, C = x.shape
        x = x.view(B, T*C)
        x = self.act_fn(self.linear1(x))
        x = self.act_fn(self.linear2(x))
        x = self.linear3(x)
        
        return x

# %% [markdown]
# # Define the model, optimizer and loss function

# %%
model = MLP(vocab_size=vocab_size, context_size=context_size, n_embd=5)
optimizer = torch.optim.Adam(params=model.parameters(), lr=1e-2)
loss_fn = nn.CrossEntropyLoss()

# %%
def list_to_characters(array):
    strings = []
    for v in array:
        string = [itos[idx] for idx in v]
        strings.append(string)
        
    return strings

# %% [markdown]
# # Model infernce

# %%
def model_inference(model, dataloader):
    model.eval()
    with torch.inference_mode():
        X, y = next(iter(dataloader))
        logits = model(X)
        percents = torch.softmax(logits, dim=1)
        preds = torch.argmax(percents, dim=1)
        preds_array = [idx_array.item() for idx_array in preds]
        labels_array = [label_array.item() for label_array in y]
        print(preds)
        print("\n")
        batches = [batch for batch in X]
        separated_inputs = [batch.tolist() for batch in batches]
        print(f"the batches are {list_to_characters(array=separated_inputs)}\n")
        print(f"model predicted {[itos[idx] for idx in preds_array]}\n")
        print(f"expected --> {[itos[label] for label in labels_array]}\n")

# %%
model_inference(model=model, dataloader=train_dataloader)
# Out:
# tensor([39, 24, 39, 39,  6, 24,  9, 41, 26, 19, 39, 29, 39, 44, 39,  9, 39, 39,
#         18, 22, 39, 52, 45, 20, 39, 45, 39,  6, 29, 38, 39, 39, 39, 18, 22, 39,
#         39,  2, 52, 38, 39, 39, 36, 13, 21, 38, 10, 22, 39, 39, 22, 52, 22, 21,
#         39, 22, 32, 39, 52, 39, 18, 39, 41, 39])
#
#
# the batches are [['.', '.', '.', 'E'], ['.', '.', '.', 'S'], ['.', '.', '.', 'K'], ['.', '.', '.', 'P'], ['N', 'o', 'e', 'l'], ['.', '.', '.', 'S'], ['.', '.', 'Q', 'u'], ['.', '.', 'L', 'e'], ['a', 'r', 'g', 'a'], ['.', 'V', 'e', 'r'], ['.', '.', '.', 'W'], ['i', 't', 'z', 'i'], ['.', '.', '.', '.'], ['C', 'h', 'e', 'r'], ['.', '.', '.', 'I'], ['.', '.', 'M', 'i'], ['.', '.', '.', '.'], ['.', '.', 'P', 'r'], ['.', 'I', 'v', 'a'], ['a', 'r', 'y', 'n'], ['.', '.', '.', 'I'], ['o', 'n', 'i', 'e'], ['e', 's', 't', 'i'], ['m', 'o', 'n', 'a'], ['.', '.', '.', 'F'], ['e', 'r', 'm', 'i'], ['.', '.', 'M', 'a'], ['.', 'D', 'e', 'l'], ['.', 'S', 'i', 'm'], ['l', 'v', 'i', 's'], ['M', 'a', 'r', 'g'], ['.', '.', '.', 'T'], ['.', '.', '.', '.'], ['.', '.', 'W', 'a'], ['.', '.', '.', 'Z'], ['.', '.', '.', 'J'], ['.', '.', 'P', 'a'], ['e', 'y', 'a', 'n'], ['.', 'E', 'y', 'v'], ['l', 'o', 't', 'i'], ['.', '.', 'J', 'a'], ['d', 'h', 'a', 'm'], ['W', 'o', 'r', 'l'], ['i', 'l', 'o', 'm'], ['e', 'l', 'l', 'e'], ['r', 'o', 'l', 'd'], ['l', 'i', 'n', 'e'], ['.', '.', '.', 'C'], ['.', '.', '.', '.'], ['.', '.', '.', '.'], ['.', '.', 'A', 'l'], ['.', 'N', 'i', 'e'], ['.', '.', 'V', 'i'], ['S', 'a', 'r', 'i'], ['e', 'l', 'i', 'a'], ['.', '.', 'A', 'p'], ['h', 'a', 'n', 'i'], ['.', '.', 'M', 'a'], ['i', 's', 'h', 'o'], ['.', '.', '.', '.'], ['.', '.', 'C', 'a'], ['.', '.', '.', '.'], ['.', 'A', 'n', 'n'], ['a', 'c', 'i', 'e']]
#
# model predicted ['q', 'f', 'q', 'q', 'u', 'f', 'R', 'j', 'A', 'W', 'q', 'I', 'q', 'g', 'q', 'R', 'q', 'q', 'v', 'l', 'q', 't', 'O', 'o', 'q', 'O', 'q', 'u', 'I', 'd', 'q', 'q', 'q', 'v', 'l', 'q', 'q', 'T', 't', 'd', 'q', 'q', 'X', 'c', 'G', 'd', 'K', 'l', 'q', 'q', 'l', 't', 'l', 'G', 'q', 'l', 'n', 'q', 't', 'q', 'v', 'q', 'j', 'q']
#
# expected --> ['v', 'a', 'i', 'a', 'a', 'h', 'i', 's', 'r', 'l', 'i', 'e', 'B', 'i', 'l', 't', 'U', 'i', 'n', '.', 'l', 'c', 'n', '.', 'r', 't', 'r', 'm', 'c', '.', 'a', 'r', 'P', 's', 'a', 'e', 'r', 'i', 'o', 'l', 'n', '.', 'e', 'e', '.', '.', '.', 'h', 'M', 'R', 'f', 'l', 'v', 't', '.', 'r', 'a', 't', 'p', 'L', 'r', 'D', 'i', '.']

# %% [markdown]
# # Training loop

# %%
def train_model(model, dataloader, loss_fn, optimizer, epochs):
    model.train()
    for epoch in range(epochs):
        for batch, (X, y) in enumerate(dataloader):
            logits = model(X)
            loss = loss_fn(logits, y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if batch % 5000 == 0:
                print(f"loss for batch {batch} --> {loss} at epoch {epoch}")
    print(f"loss for the very last batch --> {loss}")

# %%
train_model(model=model, dataloader=train_dataloader, loss_fn=loss_fn, optimizer=optimizer, epochs=10)
# Out:
# loss for batch 0 --> 3.9813597202301025 at epoch 0
# loss for batch 5000 --> 2.2622315883636475 at epoch 0
# loss for batch 10000 --> 2.479404926300049 at epoch 0
# loss for batch 15000 --> 2.166165351867676 at epoch 0
# loss for batch 20000 --> 2.243795156478882 at epoch 0
# loss for batch 25000 --> 2.5603160858154297 at epoch 0
# loss for batch 30000 --> 2.4674558639526367 at epoch 0
# loss for batch 35000 --> 2.5853469371795654 at epoch 0
# loss for batch 40000 --> 2.2452845573425293 at epoch 0
# loss for batch 45000 --> 2.141946792602539 at epoch 0
# loss for batch 50000 --> 2.365069627761841 at epoch 0
# loss for batch 55000 --> 2.202312469482422 at epoch 0
# loss for batch 60000 --> 2.0946226119995117 at epoch 0
# loss for batch 65000 --> 2.005415916442871 at epoch 0
# loss for batch 70000 --> 2.092287063598633 at epoch 0
# loss for batch 75000 --> 2.029737710952759 at epoch 0
# loss for batch 80000 --> 2.0311062335968018 at epoch 0
# loss for batch 85000 --> 2.1530752182006836 at epoch 0
# loss for batch 0 --> 2.084878444671631 at epoch 1
# loss for batch 5000 --> 2.1730520725250244 at epoch 1
# loss for batch 10000 --> 2.3268532752990723 at epoch 1
# loss for batch 15000 --> 2.366291046142578 at epoch 1
# loss for batch 20000 --> 2.0766043663024902 at epoch 1
# loss for batch 25000 --> 2.5011677742004395 at epoch 1
# loss for batch 30000 --> 2.153536796569824 at epoch 1
# loss for batch 35000 --> 1.9447780847549438 at epoch 1
# loss for batch 40000 --> 2.4208855628967285 at epoch 1
# loss for batch 45000 --> 2.1237008571624756 at epoch 1
# loss for batch 50000 --> 2.3553414344787598 at epoch 1
# loss for batch 55000 --> 1.9674314260482788 at epoch 1
# loss for batch 60000 --> 2.3079864978790283 at epoch 1
# loss for batch 65000 --> 1.9888800382614136 at epoch 1
# loss for batch 70000 --> 2.0747106075286865 at epoch 1
# loss for batch 75000 --> 2.0585362911224365 at epoch 1
# loss for batch 80000 --> 2.0865228176116943 at epoch 1
# loss for batch 85000 --> 2.0564839839935303 at epoch 1
# loss for batch 0 --> 2.0615079402923584 at epoch 2
# loss for batch 5000 --> 2.099252700805664 at epoch 2
# loss for batch 10000 --> 2.226087808609009 at epoch 2
# loss for batch 15000 --> 1.863753318786621 at epoch 2
# loss for batch 20000 --> 2.19604754447937 at epoch 2
# loss for batch 25000 --> 2.0580203533172607 at epoch 2
# loss for batch 30000 --> 2.0627920627593994 at epoch 2
# loss for batch 35000 --> 2.1174278259277344 at epoch 2
# loss for batch 40000 --> 2.0146420001983643 at epoch 2
# loss for batch 45000 --> 2.217808246612549 at epoch 2
# loss for batch 50000 --> 2.3391058444976807 at epoch 2
# loss for batch 55000 --> 2.2053544521331787 at epoch 2
# loss for batch 60000 --> 2.327096462249756 at epoch 2
# loss for batch 65000 --> 2.1596648693084717 at epoch 2
# loss for batch 70000 --> 2.2386178970336914 at epoch 2
# loss for batch 75000 --> 2.2019503116607666 at epoch 2
# loss for batch 80000 --> 2.357567071914673 at epoch 2
# loss for batch 85000 --> 1.9520916938781738 at epoch 2
# loss for batch 0 --> 2.361236572265625 at epoch 3
# loss for batch 5000 --> 2.486776351928711 at epoch 3
# loss for batch 10000 --> 1.965779423713684 at epoch 3
# loss for batch 15000 --> 2.015251398086548 at epoch 3
# loss for batch 20000 --> 2.2049760818481445 at epoch 3
# loss for batch 25000 --> 2.063042640686035 at epoch 3
# loss for batch 30000 --> 2.1025161743164062 at epoch 3
# loss for batch 35000 --> 2.579861640930176 at epoch 3
# loss for batch 40000 --> 2.173166275024414 at epoch 3
# loss for batch 45000 --> 2.220163583755493 at epoch 3
# loss for batch 50000 --> 2.4024157524108887 at epoch 3
# loss for batch 55000 --> 2.330765724182129 at epoch 3
# loss for batch 60000 --> 2.1838760375976562 at epoch 3
# loss for batch 65000 --> 1.9277148246765137 at epoch 3
# loss for batch 70000 --> 2.377007246017456 at epoch 3
# loss for batch 75000 --> 2.3017830848693848 at epoch 3
# loss for batch 80000 --> 2.2921009063720703 at epoch 3
# loss for batch 85000 --> 2.1114954948425293 at epoch 3
# loss for batch 0 --> 2.583730936050415 at epoch 4
# loss for batch 5000 --> 2.329373598098755 at epoch 4
# loss for batch 10000 --> 2.2474381923675537 at epoch 4
# loss for batch 15000 --> 2.4487578868865967 at epoch 4
# loss for batch 20000 --> 2.1209118366241455 at epoch 4
# loss for batch 25000 --> 2.0733981132507324 at epoch 4
# loss for batch 30000 --> 2.096245288848877 at epoch 4
# loss for batch 35000 --> 2.07383394241333 at epoch 4
# loss for batch 40000 --> 2.134420871734619 at epoch 4
# loss for batch 45000 --> 1.8995345830917358 at epoch 4
# loss for batch 50000 --> 2.306708335876465 at epoch 4
# loss for batch 55000 --> 2.2366409301757812 at epoch 4
# loss for batch 60000 --> 2.1935513019561768 at epoch 4
# loss for batch 65000 --> 1.9961023330688477 at epoch 4
# loss for batch 70000 --> 2.292677164077759 at epoch 4
# loss for batch 75000 --> 2.336918354034424 at epoch 4
# loss for batch 80000 --> 2.1743557453155518 at epoch 4
# loss for batch 85000 --> 2.056030035018921 at epoch 4
# loss for batch 0 --> 2.0012829303741455 at epoch 5
# loss for batch 5000 --> 2.1458444595336914 at epoch 5
# loss for batch 10000 --> 1.9359004497528076 at epoch 5
# loss for batch 15000 --> 2.0835516452789307 at epoch 5
# loss for batch 20000 --> 2.249323844909668 at epoch 5
# loss for batch 25000 --> 2.4554474353790283 at epoch 5
# loss for batch 30000 --> 1.888350486755371 at epoch 5
# loss for batch 35000 --> 2.1596641540527344 at epoch 5
# loss for batch 40000 --> 2.519259452819824 at epoch 5
# loss for batch 45000 --> 2.04984974861145 at epoch 5
# loss for batch 50000 --> 2.3678476810455322 at epoch 5
# loss for batch 55000 --> 2.2336483001708984 at epoch 5
# loss for batch 60000 --> 2.034162998199463 at epoch 5
# loss for batch 65000 --> 2.118274450302124 at epoch 5
# loss for batch 70000 --> 2.097667932510376 at epoch 5
# loss for batch 75000 --> 2.1268246173858643 at epoch 5
# loss for batch 80000 --> 2.2665727138519287 at epoch 5
# loss for batch 85000 --> 2.2374885082244873 at epoch 5
# loss for batch 0 --> 2.39543080329895 at epoch 6
# loss for batch 5000 --> 2.305621862411499 at epoch 6
# loss for batch 10000 --> 2.0629489421844482 at epoch 6
# loss for batch 15000 --> 2.2994680404663086 at epoch 6
# loss for batch 20000 --> 1.9894976615905762 at epoch 6
# loss for batch 25000 --> 2.1686618328094482 at epoch 6
# loss for batch 30000 --> 2.1804559230804443 at epoch 6
# loss for batch 35000 --> 2.131230115890503 at epoch 6
# loss for batch 40000 --> 1.9926908016204834 at epoch 6
# loss for batch 45000 --> 1.9818038940429688 at epoch 6
# loss for batch 50000 --> 2.290573835372925 at epoch 6
# loss for batch 55000 --> 2.0156548023223877 at epoch 6
# loss for batch 60000 --> 2.292854070663452 at epoch 6
# loss for batch 65000 --> 2.0335934162139893 at epoch 6
# loss for batch 70000 --> 2.451784372329712 at epoch 6
# loss for batch 75000 --> 2.2244672775268555 at epoch 6
# loss for batch 80000 --> 2.1771128177642822 at epoch 6
# loss for batch 85000 --> 2.391248941421509 at epoch 6
# loss for batch 0 --> 2.348283529281616 at epoch 7
# loss for batch 5000 --> 2.1032145023345947 at epoch 7
# loss for batch 10000 --> 1.9926705360412598 at epoch 7
# loss for batch 15000 --> 1.969645380973816 at epoch 7
# loss for batch 20000 --> 2.4052538871765137 at epoch 7
# loss for batch 25000 --> 2.0302071571350098 at epoch 7
# loss for batch 30000 --> 2.2284538745880127 at epoch 7
# loss for batch 35000 --> 2.097759485244751 at epoch 7
# loss for batch 40000 --> 2.047680139541626 at epoch 7
# loss for batch 45000 --> 2.198981523513794 at epoch 7
# loss for batch 50000 --> 2.3531148433685303 at epoch 7
# loss for batch 55000 --> 2.3194520473480225 at epoch 7
# loss for batch 60000 --> 1.9542396068572998 at epoch 7
# loss for batch 65000 --> 2.4388911724090576 at epoch 7
# loss for batch 70000 --> 2.1803674697875977 at epoch 7
# loss for batch 75000 --> 2.3415145874023438 at epoch 7
# loss for batch 80000 --> 1.9294743537902832 at epoch 7
# loss for batch 85000 --> 2.1947522163391113 at epoch 7
# loss for batch 0 --> 1.9889254570007324 at epoch 8
# loss for batch 5000 --> 2.021639585494995 at epoch 8
# loss for batch 10000 --> 2.0153801441192627 at epoch 8
# loss for batch 15000 --> 2.1521670818328857 at epoch 8
# loss for batch 20000 --> 2.536428451538086 at epoch 8
# loss for batch 25000 --> 2.2592179775238037 at epoch 8
# loss for batch 30000 --> 1.8687548637390137 at epoch 8
# loss for batch 35000 --> 2.0572400093078613 at epoch 8
# loss for batch 40000 --> 1.9253416061401367 at epoch 8
# loss for batch 45000 --> 2.1197359561920166 at epoch 8
# loss for batch 50000 --> 2.1049890518188477 at epoch 8
# loss for batch 55000 --> 2.39925479888916 at epoch 8
# loss for batch 60000 --> 2.070173501968384 at epoch 8
# loss for batch 65000 --> 2.5571060180664062 at epoch 8
# loss for batch 70000 --> 2.4489805698394775 at epoch 8
# loss for batch 75000 --> 2.16780686378479 at epoch 8
# loss for batch 80000 --> 1.9211959838867188 at epoch 8
# loss for batch 85000 --> 1.9997745752334595 at epoch 8
# loss for batch 0 --> 2.168046474456787 at epoch 9
# loss for batch 5000 --> 2.152620553970337 at epoch 9
# loss for batch 10000 --> 2.121300220489502 at epoch 9
# loss for batch 15000 --> 2.004804849624634 at epoch 9
# loss for batch 20000 --> 1.9707186222076416 at epoch 9
# loss for batch 25000 --> 2.4294774532318115 at epoch 9
# loss for batch 30000 --> 2.0069541931152344 at epoch 9
# loss for batch 35000 --> 2.2000322341918945 at epoch 9
# loss for batch 40000 --> 2.0632145404815674 at epoch 9
# loss for batch 45000 --> 2.254762649536133 at epoch 9
# loss for batch 50000 --> 2.3894221782684326 at epoch 9
# loss for batch 55000 --> 2.339176654815674 at epoch 9
# loss for batch 60000 --> 2.0728766918182373 at epoch 9
# loss for batch 65000 --> 2.2253074645996094 at epoch 9
# loss for batch 70000 --> 2.2941412925720215 at epoch 9
# loss for batch 75000 --> 2.105440139770508 at epoch 9
# loss for batch 80000 --> 2.342977285385132 at epoch 9
# loss for batch 85000 --> 1.9456148147583008 at epoch 9
# loss for the very last batch --> 2.503504991531372

# %% [markdown]
# # Test the model

# %%
model_inference(model=model, dataloader=train_dataloader)
# Out:
# tensor([ 9,  0, 23,  9, 34, 22, 43,  0, 38, 22, 32, 23, 23, 22, 22, 52,  9,  0,
#         22,  9,  0, 43,  9, 34, 11, 23, 32, 23,  9,  0, 11,  9,  0,  0,  0, 22,
#         11, 43, 23,  0, 38,  0, 43, 22, 23, 23, 11, 22, 34, 38, 22,  9,  0,  0,
#         23, 33,  0, 43, 43, 11, 11, 43,  9, 22])
#
#
# the batches are [['.', '.', '.', '.'], ['i', 'k', 'k', 'a'], ['.', 'F', 'a', 'n'], ['.', '.', '.', '.'], ['.', '.', '.', 'C'], ['r', 'c', 'e', 'l'], ['.', 'C', 'l', 'a'], ['r', 'r', 'a', 'l'], ['C', 'h', 'a', 'n'], ['.', '.', '.', 'E'], ['J', 'e', 'a', 'n'], ['V', 'e', 'r', 'n'], ['u', 'a', 'n', 'n'], ['.', '.', 'K', 'o'], ['.', '.', '.', 'A'], ['h', 'r', 'i', 's'], ['.', '.', '.', '.'], ['n', 'e', 't', 'a'], ['a', 'n', 'e', 'l'], ['.', '.', '.', '.'], ['u', 't', 'h', 'a'], ['.', '.', 'P', 'a'], ['.', '.', '.', '.'], ['.', '.', '.', 'S'], ['.', '.', '.', 'L'], ['K', 'a', 'l', 'l'], ['n', 'e', 's', 'i'], ['e', 'l', 'y', 'n'], ['.', '.', '.', '.'], ['g', 'g', 'i', 'e'], ['.', '.', '.', 'H'], ['.', '.', '.', '.'], ['A', 'n', 'n', 'a'], ['n', 'c', 'i', 'a'], ['n', 'n', 'i', 'e'], ['.', '.', '.', 'E'], ['i', 'e', 's', 'h'], ['.', 'C', 'o', 'r'], ['H', 'a', 'r', 'v'], ['t', 'e', 'l', 'l'], ['p', 'h', 'a', 'n'], ['a', 'r', 'o', 'n'], ['.', 'C', 'a', 'r'], ['.', '.', '.', 'A'], ['C', 'r', 'y', 's'], ['.', 'A', 'r', 't'], ['T', 'i', 'n', 'i'], ['.', '.', '.', 'E'], ['.', '.', '.', 'S'], ['S', 'h', 'a', 'n'], ['.', '.', 'L', 'e'], ['.', '.', '.', '.'], ['l', 'e', 'n', 'e'], ['e', 's', 's', 'a'], ['T', 'o', 'n', 'i'], ['.', 'J', 'a', 'c'], ['e', 'r', 'o', 'y'], ['.', 'M', 'o', 'r'], ['.', '.', 'W', 'e'], ['.', 'A', 'n', 'j'], ['.', 'L', 'y', 'n'], ['.', '.', 'B', 'e'], ['.', '.', '.', '.'], ['Y', 'a', 't', 'e']]
#
# model predicted ['R', '.', 'e', 'R', 'h', 'l', 'r', '.', 'd', 'l', 'n', 'e', 'e', 'l', 'l', 't', 'R', '.', 'l', 'R', '.', 'r', 'R', 'h', 'a', 'e', 'n', 'e', 'R', '.', 'a', 'R', '.', '.', '.', 'l', 'a', 'r', 'e', '.', 'd', '.', 'r', 'l', 'e', 'e', 'a', 'l', 'h', 'd', 'l', 'R', '.', '.', 'e', 'k', '.', 'r', 'r', 'a', 'a', 'r', 'R', 'l']
#
# expected --> ['M', '.', 'n', 'M', 'h', 'l', 'r', 'd', 'd', 'l', 'n', 'a', 'a', 'r', 'r', 't', 'E', '.', 'l', 'S', 'n', 'u', 'A', 'h', 'i', 'e', 'm', '.', 'O', '.', 'o', 'M', 'l', '.', '.', 'a', 'a', 'l', 'e', 'e', 'i', '.', 'o', 'n', 't', 'e', 't', 'v', 'h', 'd', 's', 'A', '.', '.', 't', 'q', '.', 'r', 'n', 'a', 'n', 'r', 'D', 's']
